# %% [markdown]
# # Proyek Analisis Data: [Air Quality Dataset]
# - **Nama:** Elvan Nasrul
# - **Email:** elopvan23@gmail.com
# - **ID Dicoding:** elvan_nasrul

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1 : Bagaimana tren kualitas udara dari waktu ke waktu, dan bagaimana korelasinya dengan faktor lingkungan (misalnya suhu, kelembapan, dan kecepatan angin)?
# - Pertanyaan 2 : Wilayah geografis (atau periode waktu) manakah yang menunjukkan tingkat polusi udara tertinggi dan terendah, dan wawasan apa yang dapat diambil mengenai penyebab tren ini?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
df1 = pd.read_csv('./Data/PRSA_Data_Guanyuan_20130301-20170228.csv')
df2 = pd.read_csv('./Data/PRSA_Data_Aotizhongxin_20130301-20170228.csv')
df3 = pd.read_csv('./Data/PRSA_Data_Tiantan_20130301-20170228.csv')

# %% [markdown]
# ### Assessing Data

# %%
print("Info dataset Guanyuan")
df1.info()
print(df1.describe())
# Out:
# Info dataset Guanyuan
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34448 non-null  float64
#  6   PM10     34635 non-null  float64
#  7   SO2      34590 non-null  float64
#  8   NO2      34405 non-null  float64
#  9   CO       33311 non-null  float64
#  10  O3       33891 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# ...

# %%
print("Info dataset Aotizhongxin")
df2.info()
print(df2.describe())
# Out:
# Info dataset Aotizhongxin
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# ...

# %%
print("Info dataset Tiantan")
df3.info()
print(df3.describe())
# Out:
# Info dataset Tiantan
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34387 non-null  float64
#  6   PM10     34467 non-null  float64
#  7   SO2      33946 non-null  float64
#  8   NO2      34320 non-null  float64
#  9   CO       33938 non-null  float64
#  10  O3       34221 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# ...

# %%
print("Missing values dataset Guanyuan")
print(df1.isna().sum())
# Out:
# Missing values dataset Guanyuan
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       616
# PM10        429
# SO2         474
# NO2         659
# CO         1753
# O3         1173
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
print("Missing values dataset Aotizhongxin")
print(df2.isna().sum())
# Out:
# Missing values dataset Aotizhongxin
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
print("Missing values dataset Tiantan")
print(df3.isna().sum())
# Out:
# Missing values dataset Tiantan
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       677
# PM10        597
# SO2        1118
# NO2         744
# CO         1126
# O3          843
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
print("Duplicate dataset Guanyuan: ", df1.duplicated().sum())
# Out:
# Duplicate dataset Guanyuan:  0

# %%
print("Duplicate dataset Aotizhongxin: ", df2.duplicated().sum())
# Out:
# Duplicate dataset Aotizhongxin:  0

# %%
print("Duplicate dataset Tiantan: ", df3.duplicated().sum())
# Out:
# Duplicate dataset Tiantan:  0

# %% [markdown]
# **Insight:**
# - Ketiga dataset memiliki missing value
# - Ketiga dataset tidak memiliki data duplikat

# %% [markdown]
# ### Cleaning Data

# %%
df1_cleaned = df1.dropna()
df2_cleaned = df2.dropna()
df3_cleaned = df3.dropna()

# %%
for df_cleaned in [df1_cleaned, df2_cleaned, df3_cleaned]:
    df_cleaned['year'] = df_cleaned['year'].astype(int)
    df_cleaned['month'] = df_cleaned['month'].astype(int)
    df_cleaned['day'] = df_cleaned['day'].astype(int)
    df_cleaned['hour'] = df_cleaned['hour'].astype(int)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15588\2172068180.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['year'] = df_cleaned['year'].astype(int)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15588\2172068180.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['month'] = df_cleaned['month'].astype(int)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15588\2172068180.py:4: SettingWithCopyWarning:
# ...

# %%
for df_cleaned in [df1_cleaned, df2_cleaned, df3_cleaned]:
    df_cleaned['date'] = pd.to_datetime(df_cleaned['year'].astype(str) + '-' +
                                        df_cleaned['month'].astype(str) + '-' +
                                        df_cleaned['day'].astype(str))
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15588\8880776.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['date'] = pd.to_datetime(df_cleaned['year'].astype(str) + '-' +
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15588\8880776.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['date'] = pd.to_datetime(df_cleaned['year'].astype(str) + '-' +
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15588\8880776.py:2: SettingWithCopyWarning:
# ...

# %% [markdown]
# ### Explore ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
pm25_trend_guanyuan = df1_cleaned.groupby('date')['PM2.5'].mean().reset_index()
pm25_trend_aotizhongxin = df2_cleaned.groupby('date')['PM2.5'].mean().reset_index()
pm25_trend_tiantan = df3_cleaned.groupby('date')['PM2.5'].mean().reset_index()

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
plt.figure(figsize=(12, 6))
plt.plot(pm25_trend_guanyuan['date'], pm25_trend_guanyuan['PM2.5'], marker='o', color='b', label='Guanyuan')
plt.plot(pm25_trend_aotizhongxin['date'], pm25_trend_aotizhongxin['PM2.5'], marker='o', color='g', label='Aotizhongxin')
plt.plot(pm25_trend_tiantan['date'], pm25_trend_tiantan['PM2.5'], marker='o', color='r', label='Tiantan')
plt.title("Tren PM2.5 dari 2013 hingga 2017 untuk Setiap Stasiun", fontsize=16)
plt.xlabel("Tanggal")
plt.ylabel("Rata-rata PM2.5")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# %%
correlation_df = df1_cleaned[['PM2.5', 'TEMP', 'DEWP', 'WSPM']].corr()
sns.heatmap(correlation_df, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Korelasi antara PM2.5 dan Faktor Lingkungan di Guanyuan', fontsize=16)
plt.show()

# %%
correlation_df = df2_cleaned[['PM2.5', 'TEMP', 'DEWP', 'WSPM']].corr()
sns.heatmap(correlation_df, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Korelasi antara PM2.5 dan Faktor Lingkungan di Aotizhongxin', fontsize=16)
plt.show()

# %%
correlation_df = df3_cleaned[['PM2.5', 'TEMP', 'DEWP', 'WSPM']].corr()
sns.heatmap(correlation_df, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Korelasi antara PM2.5 dan Faktor Lingkungan di Tiantan', fontsize=16)
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
mean_pm25_by_station = pd.DataFrame({
    'Station': ['Guanyuan', 'Aotizhongxin', 'Tiantan'],
    'Mean PM2.5': [
        df1_cleaned['PM2.5'].mean(),
        df2_cleaned['PM2.5'].mean(),
        df3_cleaned['PM2.5'].mean()
    ]
})

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=mean_pm25_by_station, x='Station', y='Mean PM2.5', palette='Blues')
plt.title('Rata-rata PM2.5 Berdasarkan Stasiun', fontsize=16)
plt.xlabel('Stasiun')
plt.ylabel('Rata-rata PM2.5')
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15588\3422287440.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=mean_pm25_by_station, x='Station', y='Mean PM2.5', palette='Blues')

# %%
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Fall'

for df_cleaned in [df1_cleaned, df2_cleaned, df3_cleaned]:
    df_cleaned['season'] = df_cleaned['month'].apply(get_season)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15588\3736085235.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['season'] = df_cleaned['month'].apply(get_season)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15588\3736085235.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['season'] = df_cleaned['month'].apply(get_season)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15588\3736085235.py:12: SettingWithCopyWarning:
# ...

# %%
seasonal_pm25_guanyuan = df1_cleaned.groupby('season')['PM2.5'].mean().reset_index()
seasonal_pm25_aotizhongxin = df2_cleaned.groupby('season')['PM2.5'].mean().reset_index()
seasonal_pm25_tiantan = df3_cleaned.groupby('season')['PM2.5'].mean().reset_index()

# %%
seasonal_pm25_combined = pd.DataFrame({
    'Season': seasonal_pm25_guanyuan['season'],
    'Guanyuan': seasonal_pm25_guanyuan['PM2.5'],
    'Aotizhongxin': seasonal_pm25_aotizhongxin['PM2.5'],
    'Tiantan': seasonal_pm25_tiantan['PM2.5']
})

# %%
seasonal_pm25_melted = seasonal_pm25_combined.melt(id_vars='Season', var_name='Station', value_name='PM2.5')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=seasonal_pm25_melted, x='Season', y='PM2.5', hue='Station', palette='Set2')
plt.title('Rata-rata PM2.5 Berdasarkan Musim untuk Setiap Stasiun', fontsize=16)
plt.xlabel('Musim')
plt.ylabel('Rata-rata PM2.5')
plt.legend(title='Stasiun')
plt.show()

# %%
combined_df_cleaned = pd.concat([df1_cleaned, df2_cleaned, df3_cleaned])
bins = [0, 50, 100, combined_df_cleaned['PM2.5'].max()]
labels = ['Low', 'Medium', 'High']
combined_df_cleaned['pm25_category'] = pd.cut(combined_df_cleaned['PM2.5'], bins=bins, labels=labels)

# %%
custom_palette = ["#FFCC99","#FF9999", "#99FF99"]

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='pm25_category', data=combined_df_cleaned, palette=custom_palette)
plt.title('Distribusi Kategori PM2.5 (Low, Medium, High)', fontsize=16)
plt.xlabel('Kategori PM2.5')
plt.ylabel('Frekuensi')
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15588\2034396795.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='pm25_category', data=combined_df_cleaned, palette=custom_palette)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - **Conclution pertanyaan 1 :**
# *   Analisis tren PM2.5 dari tahun 2013 hingga 2017 menunjukkan fluktuasi yang signifikan di ketiga stasiun. Terlihat bahwa konsentrasi PM2.5 cenderung lebih tinggi pada bulan-bulan tertentu. Hal ini menunjukkan bahwa polusi udara memiliki pola musiman yang jelas.
#
# *   Analisis korelasi antara PM2.5 dan faktor lingkungan seperti suhu, kelembapan, dan kecepatan angin menunjukkan bahwa terdapat hubungan yang signifikan antara kualitas udara dan variabel tersebut.
#
#
#
#
# - **Conclution pertanyaan 2  :**
#
#
# *   Rata-rata PM2.5 di ketiga stasiun menunjukkan variasi yang mencolok. Stasiun Guanyuan mencatat tingkat PM2.5 tertinggi disusul oleh Aotizhongxin, lalu Tiantan.
#
# *   Data menunjukkan bahwa kualitas udara di ketiga stasiun lebih buruk pada musim dingin, dengan rata-rata PM2.5 yang lebih tinggi dibandingkan musim lainnya.

# %%
df1_cleaned.to_csv('Guanyuan_cleaned.csv', index=False)
df2_cleaned.to_csv('Aotizhongxin_cleaned.csv', index=False)
df3_cleaned.to_csv('Tiantan_cleaned.csv', index=False)
